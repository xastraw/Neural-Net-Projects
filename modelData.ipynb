# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
#from medmnist import OrganMNIST3D
from model import myNet

# %%
model = myNet()
model.load_weights('checkpoints/epoch_60.weights.h5') 
print("Model loaded successfully from epoch_2.weights.h5")
# Out:
# Model loaded successfully from epoch_2.weights.h5
# x:\Anaconda\envs\neural-net-minst\Lib\site-packages\keras\src\saving\saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 30 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
plot_model(model, to_file = 'neuralnet_model.png', show_shapes = True, show_layer_names = True)

# %%
fig, ax1 = plt.subplots(figsize=(8,5))

# Plot Loss on left axis
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss', color='tab:red')
ax1.plot(training_history.history['loss'], color='tab:red', label='Training Loss')
ax1.tick_params(axis='y', labelcolor='tab:red')

# Create a second y-axis for Accuracy
ax2 = ax1.twinx()
ax2.set_ylabel('Accuracy', color='tab:blue')
ax2.plot(training_history.history['accuracy'], color='tab:blue', label='Training Accuracy')
ax2.tick_params(axis='y', labelcolor='tab:blue')

# Title and legend
fig.suptitle('Loss & Accuracy Over Epochs')
fig.tight_layout()

# Combined legend
lines = ax1.get_lines() + ax2.get_lines()
labels = [line.get_label() for line in lines]
plt.legend(lines, labels, loc='lower right')

plt.show()

# %%
test_loss, test_accuracy = model.evaluate(x_test, y_test, verbose=0)
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")
