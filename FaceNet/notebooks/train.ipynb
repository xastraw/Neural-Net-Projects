# %%
import sys
sys.path.append("..")   # makes project root visible

from utils.dataset import get_vggface2_loaders
from utils.model import FaceEncoder
from utils.trainer import train
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 6
#       4 from utils.dataset import get_vggface2_loaders
#       5 from utils.model import FaceEncoder
# ----> 6 from utils.trainer import train
#
# File c:\Users\xande\OneDrive\Documents\College\Machine Learning\Neural Net Projects\FaceNet\notebooks\..\utils\trainer.py:3
#       1 import torch
#       2 from torch import nn, optim
# ----> 3 from tqdm import tqdm
#       5 def train(model, train_loader, epochs, device):
#       6     model.to(device)
#
# ModuleNotFoundError: No module named 'tqdm'

# %%
train_path = "/content/train"
test_path = "/content/test"

batch_size = 64
epochs = 10
embedding_size = 512

# %%
train_loader, test_loader = get_vggface2_loaders(
    train_path, test_path, batch_size
)

# %%
model = FaceEncoder(embedding_size)
device = "cuda" if torch.cuda.is_available() else "cpu"
print(device)

# %%
# # load data
# train_loader, test_loader = get_vggface2_loaders(train_path, test_path)

# # build model
# model = FaceEncoder()

# # train
# train(model, train_loader, epochs=10, device="cuda")
